# %%
import matplotlib.pyplot as plt

from googleapiclient.discovery import build 
import pandas as pd
import seaborn as sns
from datetime import datetime


api_key = 'AIzaSyDQLPUNa97noGvgDkH9u00kUc7HM2P_mWA' 
#channel_id = 'UCHnyfMqiRRG1u-2MsSQLbXA'
channel_ids = [
            'UCDOgqFPOaGETedGekPLDq-w',  # @birdview3503
            'UC26ngasXvtR1MNdb2rTc6qA',  # @vidhaiiiitdm8113
            'UCO9yldw0ysIlhlA5TBgqofw',  # @cinematicsclubiiitdm
            'UCFBFlcfjEGOUsuFfPC-62bg',  # @auvsocietyiiitdm2840
            'UCC0_90UdP8T31E4CLBhPWWA',  # @iiitdmkancheepuram3857
            'UCl01-rcdESLiRvkvkPRkg1Q',  # @iiitdmmusicclub2549
            'UCKJFJ5ngqcXBv8Yj9HKPkRA',  # @iiitdmtv3896
            'UCQuL8Qd1L6lML-FHXmD0pqw',  # @csclubiiitdm8734
            'UCy6w-M_fRTwkcISyEaHavhQ',  # @madeitinnovationfoundation1714
            'UCYIVsibOwxldwfDLtkhQlZQ',  # @alumniiiitdmkancheepuram7870
            'UCy6aiob_WAtllF8ydQZ40xg',  # @teachinglearningcentreiiit1770
            'UCAcpmImbDHwZ_Xe3EgMFd4Q',  # @osaiiitdmkancheepuram6422
            'UCEtq0eQN9KKosnZOCX3kQew',  # @epic_iiitdm
            'UCv9jh0tfIG_65l9LQKFgDzA',  # @techaffairsiiitdm9735
            'UCcjxy9HBGdrlbw03lO4FSsQ',  # @rosmdiiitdm7914
                                                                    ]

youtube = build('youtube', 'v3', developerKey=api_key)


def get_channel_stats (youtube, channel_ids):
    all_data=[]
    request = youtube.channels().list( 
                part='snippet, contentDetails, statistics', 
                id=','.join(channel_ids))
    response = request.execute()
    for i in range(len(response['items'])):
        data=dict(Channel_name = response['items'][i]['snippet']['title'],
               Subscribers = response['items'][i]['statistics']['subscriberCount'],
               Views = response['items'][i]['statistics']['viewCount'],
               Total_videos = response['items'][i]['statistics']['videoCount'],
               playlist_id = response['items'][i]['contentDetails']['relatedPlaylists']['uploads'])
        
        all_data.append(data)
    return all_data

# %%
get_channel_stats (youtube, channel_ids)
# Out:
# [{'Channel_name': 'Teaching Learning Centre IIITDM Kancheepuram',
#   'Subscribers': '67',
#   'Views': '2300',
#   'Total_videos': '6',
#   'playlist_id': 'UUy6aiob_WAtllF8ydQZ40xg'},
#  {'Channel_name': 'AUV Society IIITDM',
#   'Subscribers': '184',
#   'Views': '11946',
#   'Total_videos': '30',
#   'playlist_id': 'UUFBFlcfjEGOUsuFfPC-62bg'},
#  {'Channel_name': 'ROSMD IIITDM',
#   'Subscribers': '0',
#   'Views': '16',
#   'Total_videos': '1',
#   'playlist_id': 'UUcjxy9HBGdrlbw03lO4FSsQ'},
#  {'Channel_name': 'IIITDM TV',
#   'Subscribers': '483',
#   'Views': '64886',
#   'Total_videos': '9',
#   'playlist_id': 'UUKJFJ5ngqcXBv8Yj9HKPkRA'},
#  {'Channel_name': 'Vidhai IIITDM',
#   'Subscribers': '143',
#   'Views': '5232',
#   'Total_videos': '102',
#   'playlist_id': 'UU26ngasXvtR1MNdb2rTc6qA'},
#  {'Channel_name': 'EPiC IIITDM',
#   'Subscribers': '11',
#   'Views': '80',
#   'Total_videos': '5',
#   'playlist_id': 'UUEtq0eQN9KKosnZOCX3kQew'},
# ...

# %%
channel_statistics = get_channel_stats (youtube, channel_ids)

# %%
channel_data = pd.DataFrame(channel_statistics)

# %%
channel_data
# Out:
#                                     Channel_name Subscribers  Views  \
# 0   Teaching Learning Centre IIITDM Kancheepuram          67   2300
# 1                             AUV Society IIITDM         184  11946
# 2                                   ROSMD IIITDM           0     16
# 3                                      IIITDM TV         483  64886
# 4                                  Vidhai IIITDM         143   5232
# 5                             TechAffairs IIITDM          16    430
# 6                                    EPiC IIITDM          11     80
# 7                              IIITDM Music Club          63   3627
# 8                                 CS CLUB IIITDM          63    893
# 9                            IIITDM Kancheepuram        1020  82499
# 10                    Alumni IIITDM Kancheepuram         123   3262
# 11                                     BiRD View         142   8070
# 12                        Cinematics Club IIITDM         348  24372
# ...

# %%
channel_data.dtypes



channel_data['Subscribers'] = pd.to_numeric(channel_data['Subscribers'])
channel_data['Views'] = pd.to_numeric(channel_data['Views'])
channel_data['Total_videos'] = pd.to_numeric(channel_data['Total_videos'])
channel_data['SubscriberViewsratio']= channel_data['Subscribers']/channel_data['Views']
channel_data['ViewsSubscriberratio']= channel_data['Views']/channel_data['Subscribers']
channel_data.dtypes
# Out:
# Channel_name             object
# Subscribers               int64
# Views                     int64
# Total_videos              int64
# playlist_id              object
# SubscriberViewsratio    float64
# ViewsSubscriberratio    float64
# dtype: object

# %%
channel_data
# Out:
#                                     Channel_name  Subscribers  Views  \
# 0   Teaching Learning Centre IIITDM Kancheepuram           67   2300
# 1                             AUV Society IIITDM          184  11946
# 2                                   ROSMD IIITDM            0     16
# 3                                      IIITDM TV          483  64886
# 4                                  Vidhai IIITDM          143   5232
# 5                             TechAffairs IIITDM           16    430
# 6                                    EPiC IIITDM           11     80
# 7                              IIITDM Music Club           63   3627
# 8                                 CS CLUB IIITDM           63    893
# 9                            IIITDM Kancheepuram         1020  82499
# 10                    Alumni IIITDM Kancheepuram          123   3262
# 11                                     BiRD View          142   8070
# 12                        Cinematics Club IIITDM          348  24372
# ...

# %%
playlist_id1 = channel_data.loc[channel_data['Channel_name']=='BiRD View','playlist_id'].iloc[0]
playlist_id2 = channel_data.loc[channel_data['Channel_name']=='TechAffairs IIITDM','playlist_id'].iloc[0]
playlist_id3= channel_data.loc[channel_data['Channel_name']=='Cinematics Club IIITDM','playlist_id'].iloc[0]
playlist_id4 = channel_data.loc[channel_data['Channel_name']=='Teaching Learning Centre IIITDM Kancheepuram','playlist_id'].iloc[0]
playlist_id5 = channel_data.loc[channel_data['Channel_name']=='EPiC IIITDM','playlist_id'].iloc[0]
playlist_id6 = channel_data.loc[channel_data['Channel_name']=='AUV Society IIITDM','playlist_id'].iloc[0]
playlist_id7 = channel_data.loc[channel_data['Channel_name']=='Vidhai IIITDM','playlist_id'].iloc[0]
playlist_id8 = channel_data.loc[channel_data['Channel_name']=='IIITDM TV','playlist_id'].iloc[0]
playlist_id9 = channel_data.loc[channel_data['Channel_name']=='CS CLUB IIITDM','playlist_id'].iloc[0]
playlist_id10 = channel_data.loc[channel_data['Channel_name']=='MaDeIT Innovation Foundation','playlist_id'].iloc[0]
playlist_id11 = channel_data.loc[channel_data['Channel_name']=='IIITDM Kancheepuram','playlist_id'].iloc[0]
#playlist_id12 = channel_data.loc[channel_data['Channel_name']=='OSA IIITDM KANCHEEPURAM','playlist_id'].iloc[0]
playlist_id13= channel_data.loc[channel_data['Channel_name']=='IIITDM Music Club','playlist_id'].iloc[0]
playlist_id14 = channel_data.loc[channel_data['Channel_name']=='Alumni IIITDM Kancheepuram','playlist_id'].iloc[0]
playlist_id15 = channel_data.loc[channel_data['Channel_name']=='ROSMD IIITDM','playlist_id'].iloc[0]

# %%
playlist_id1
# Out:
# 'UUDOgqFPOaGETedGekPLDq-w'

# %%
def get_video_ids (youtube, playlist_id):
        request = youtube.playlistItems().list(part='content Details', playlistId = playlist_id,maxResults=50)
        response = request.execute()
        
        video_ids=[]
        for i in range(len(response['items'])):
            video_ids.append(response['items'][i]['contentDetails']['videoId'])
            
        next_page_token = response.get('nextPageToken')
        more_pages = True
        
        while more_pages:
            if next_page_token is None:
                more_pages = False
            else:
                request = youtube.playlistItems().list(part='content Details', playlistId = playlist_id,maxResults=50,pageToken=next_page_token )
                response = request.execute()
                
                for i in range(len(response['items'])):
                    video_ids.append(response['items'][i]['contentDetails']['videoId'])
                next_page_token = response.get('nextPageToken')
                
                
        return video_ids

# %%
video_ids = get_video_ids (youtube, playlist_id1)+get_video_ids (youtube, playlist_id2)+get_video_ids (youtube, playlist_id3)+get_video_ids (youtube, playlist_id4)+get_video_ids (youtube, playlist_id5)+get_video_ids (youtube, playlist_id6)+get_video_ids (youtube, playlist_id7)+get_video_ids (youtube, playlist_id8)+get_video_ids (youtube, playlist_id9)+get_video_ids (youtube, playlist_id10)+get_video_ids (youtube, playlist_id11)+get_video_ids (youtube, playlist_id13)+get_video_ids (youtube, playlist_id14)+get_video_ids (youtube, playlist_id15)
video_ids1 = get_video_ids(youtube, playlist_id1)
video_ids2 = get_video_ids(youtube, playlist_id2)
video_ids3 = get_video_ids(youtube, playlist_id3)
video_ids4 = get_video_ids(youtube, playlist_id4)
video_ids5 = get_video_ids(youtube, playlist_id5)
video_ids6 = get_video_ids(youtube, playlist_id6)
video_ids7 = get_video_ids(youtube, playlist_id7)
video_ids8 = get_video_ids(youtube, playlist_id8)
video_ids9 = get_video_ids(youtube, playlist_id9)
video_ids10 = get_video_ids(youtube, playlist_id10)
video_ids11 = get_video_ids(youtube, playlist_id11)
#video_ids12 = get_video_ids(youtube, playlist_id12)
video_ids13 = get_video_ids(youtube, playlist_id13)
video_ids14 = get_video_ids(youtube, playlist_id14)
video_ids15 = get_video_ids(youtube, playlist_id15)

# %%
video_ids
# Out:
# ['0lX_-yvAv10',
#  'vx4y9Cxb61s',
#  'Tcx9tpaEvSU',
#  '_G_uKq_Ts9c',
#  'O8Gyy1H9PQk',
#  'phk9VtWTWvE',
#  'G_ku9LMWl5k',
#  'McWwmSTF0LI',
#  'dtIuwhW1TRI',
#  'zBmKsKBJP7U',
#  'iyeXLCIDI0I',
#  '8JfjupVkLlQ',
#  'm0xjAfdbnRc',
#  'KiwlbmGTOco',
#  '2jtJAKeY2kc',
#  'h7TeydAkGO0',
#  '-JLb-51qQPc',
#  '0J-LtmdKDqk',
#  'L5cItWcfFBs',
#  'FKJkCLdEito',
#  'Lk-_jM6XZio',
#  'c5tMOuDZnf8',
#  'SrBRhkZacfc',
#  'IP3oPdSexfQ',
#  'o4ZMMlGIjng',
#  'jUBE3XFA5eo',
#  'AHRNdTv7Kgs',
#  'PNgr6lWarxk',
#  'sWUpiekxQFU',
#  'FwqMWkupc9M',
#  'iFpD1zgAXhc',
#  'KvCgfgeMbr0',
#  'NEcndyQSi2Y',
#  'a0gEjABGUMQ',
#  'BANwUIxxQd0',
#  'tjfWV0t69YM',
#  'EBZqTuzAuoQ',
#  'mrJBqQNuolY',
#  'lLnOYV0Lygw',
#  'P_mjLf9dLUI',
#  'sYpkRTwafMc',
#  'pM8SwBhSQaQ',
#  'r_7brc_lu-U',
#  'xA0IKv9SV-4',
#  'eor6AZHvrfk',
#  'PJkZHD1anEQ',
#  '4xd---l6aKI',
#  '2nw8OjT2lOg',
#  '5tgvKRA0TDw',
#  'N0bjUsOFulo',
#  'YKsqorX5tr8',
#  'DPMAKkdlMNw',
#  '_-m3nRfziSo',
#  'Vr_4tPaL6Gk',
#  '_ay2vIqWfDU',
# ...

# %%
def get_video_details(youtube, video_ids):
    all_video_stats = []
    
    for i in range(0,len(video_ids)):
        request = youtube.videos().list( part='snippet, statistics', id=', '.join(video_ids[i:i+1]))
        response = request.execute()
        
        for video in response['items']:

            video_stats = dict(Title = video['snippet']['title'], 
                                          Published_date = video['snippet']['publishedAt'], 
                                          Views = video['statistics']['viewCount'], 
                                          Likes = video['statistics']['likeCount'] if 'likeCount' in video['statistics'] else 0,
                                          Comments = video['statistics']['commentCount'] if 'commentCount' in video['statistics'] else 0
                              )
            all_video_stats.append(video_stats)

    return all_video_stats

# %%
video_details = get_video_details(youtube,video_ids)

video_details1 = get_video_details(youtube, video_ids1)
video_details2 = get_video_details(youtube, video_ids2)
video_details3 = get_video_details(youtube, video_ids3)
video_details4 = get_video_details(youtube, video_ids4)
video_details5 = get_video_details(youtube, video_ids5)
video_details6 = get_video_details(youtube, video_ids6)
video_details7 = get_video_details(youtube, video_ids7)
video_details8 = get_video_details(youtube, video_ids8)
video_details9 = get_video_details(youtube, video_ids9)
video_details10 = get_video_details(youtube, video_ids10)
video_details11 = get_video_details(youtube, video_ids11)
#video_details12 = get_video_details(youtube, video_ids12)
video_details13 = get_video_details(youtube, video_ids13)
video_details14 = get_video_details(youtube, video_ids14)
video_details15 = get_video_details(youtube, video_ids15)

# %%
video_data = pd.DataFrame(video_details)

video_data1 = pd.DataFrame(video_details1)
video_data2 = pd.DataFrame(video_details2)
video_data3 = pd.DataFrame(video_details3)
video_data4 = pd.DataFrame(video_details4)
video_data5 = pd.DataFrame(video_details5)
video_data6 = pd.DataFrame(video_details6)
video_data7 = pd.DataFrame(video_details7)
video_data8 = pd.DataFrame(video_details8)
video_data9 = pd.DataFrame(video_details9)
video_data10 = pd.DataFrame(video_details10)
video_data11 = pd.DataFrame(video_details11)
#video_data12 = pd.DataFrame(video_details12)
video_data13 = pd.DataFrame(video_details13)
video_data14 = pd.DataFrame(video_details14)
video_data15 = pd.DataFrame(video_details15)

# %%
video_data['Published_date'] = pd.to_datetime (video_data['Published_date']).dt.date
video_data['Views'] = pd.to_numeric(video_data['Views'])
video_data['Likes'] = pd.to_numeric(video_data['Likes'])
video_data['Comments'] = pd.to_numeric(video_data['Comments'])
video_data['CommentViewRatio'] = video_data['Comments']/video_data['Views']




video_data1['Published_date'] = pd.to_datetime(video_data1['Published_date']).dt.date
video_data1['Views'] = pd.to_numeric(video_data1['Views'])
video_data1['Likes'] = pd.to_numeric(video_data1['Likes'])
video_data1['Comments'] = pd.to_numeric(video_data1['Comments'])
video_data1['CommentViewRatio'] = video_data1['Comments'] / video_data1['Views']

# Repeat the same operations for video_data2 to video_data15
video_data2['Published_date'] = pd.to_datetime(video_data2['Published_date']).dt.date
video_data2['Views'] = pd.to_numeric(video_data2['Views'])
video_data2['Likes'] = pd.to_numeric(video_data2['Likes'])
video_data2['Comments'] = pd.to_numeric(video_data2['Comments'])
video_data2['CommentViewRatio'] = video_data2['Comments'] / video_data2['Views']

# Repeat the above for video_data3 to video_data15
# ...

# Keep repeating the operations for video_data3 to video_data15
# ...

# Finally, you'll have all 15 DataFrames with the desired operations applied to each of them




# For video_data3
video_data3['Published_date'] = pd.to_datetime(video_data3['Published_date']).dt.date
video_data3['Views'] = pd.to_numeric(video_data3['Views'])
video_data3['Likes'] = pd.to_numeric(video_data3['Likes'])
video_data3['Comments'] = pd.to_numeric(video_data3['Comments'])
video_data3['CommentViewRatio'] = video_data3['Comments'] / video_data3['Views']

# For video_data4
video_data4['Published_date'] = pd.to_datetime(video_data4['Published_date']).dt.date
video_data4['Views'] = pd.to_numeric(video_data4['Views'])
video_data4['Likes'] = pd.to_numeric(video_data4['Likes'])
video_data4['Comments'] = pd.to_numeric(video_data4['Comments'])
video_data4['CommentViewRatio'] = video_data4['Comments'] / video_data4['Views']

# For video_data5
video_data5['Published_date'] = pd.to_datetime(video_data5['Published_date']).dt.date
video_data5['Views'] = pd.to_numeric(video_data5['Views'])
video_data5['Likes'] = pd.to_numeric(video_data5['Likes'])
video_data5['Comments'] = pd.to_numeric(video_data5['Comments'])
video_data5['CommentViewRatio'] = video_data5['Comments'] / video_data5['Views']

# Continue this pattern for video_data6 to video_data15
# ...

# Finally, the necessary operations will be applied to all 15 DataFrames consistently.


# For video_data6
video_data6['Published_date'] = pd.to_datetime(video_data6['Published_date']).dt.date
video_data6['Views'] = pd.to_numeric(video_data6['Views'])
video_data6['Likes'] = pd.to_numeric(video_data6['Likes'])
video_data6['Comments'] = pd.to_numeric(video_data6['Comments'])
video_data6['CommentViewRatio'] = video_data6['Comments'] / video_data6['Views']

# For video_data7
video_data7['Published_date'] = pd.to_datetime(video_data7['Published_date']).dt.date
video_data7['Views'] = pd.to_numeric(video_data7['Views'])
video_data7['Likes'] = pd.to_numeric(video_data7['Likes'])
video_data7['Comments'] = pd.to_numeric(video_data7['Comments'])
video_data7['CommentViewRatio'] = video_data7['Comments'] / video_data7['Views']

# For video_data8
video_data8['Published_date'] = pd.to_datetime(video_data8['Published_date']).dt.date
video_data8['Views'] = pd.to_numeric(video_data8['Views'])
video_data8['Likes'] = pd.to_numeric(video_data8['Likes'])
video_data8['Comments'] = pd.to_numeric(video_data8['Comments'])
video_data8['CommentViewRatio'] = video_data8['Comments'] / video_data8['Views']

# Continue the same pattern for video_data9 to video_data15
# ...

# Finally, the necessary operations will be applied to all 15 DataFrames consistently.


# For video_data9
video_data9['Published_date'] = pd.to_datetime(video_data9['Published_date']).dt.date
video_data9['Views'] = pd.to_numeric(video_data9['Views'])
video_data9['Likes'] = pd.to_numeric(video_data9['Likes'])
video_data9['Comments'] = pd.to_numeric(video_data9['Comments'])
video_data9['CommentViewRatio'] = video_data9['Comments'] / video_data9['Views']

# For video_data10
video_data10['Published_date'] = pd.to_datetime(video_data10['Published_date']).dt.date
video_data10['Views'] = pd.to_numeric(video_data10['Views'])
video_data10['Likes'] = pd.to_numeric(video_data10['Likes'])
video_data10['Comments'] = pd.to_numeric(video_data10['Comments'])
video_data10['CommentViewRatio'] = video_data10['Comments'] / video_data10['Views']

# For video_data11
video_data11['Published_date'] = pd.to_datetime(video_data11['Published_date']).dt.date
video_data11['Views'] = pd.to_numeric(video_data11['Views'])
video_data11['Likes'] = pd.to_numeric(video_data11['Likes'])
video_data11['Comments'] = pd.to_numeric(video_data11['Comments'])
video_data11['CommentViewRatio'] = video_data11['Comments'] / video_data11['Views']

# For video_data12
#video_data12['Published_date'] = pd.to_datetime(video_data12['Published_date']).dt.date
#video_data12['Views'] = pd.to_numeric(video_data12['Views'])
#video_data12['Likes'] = pd.to_numeric(video_data12['Likes'])
#video_data12['Comments'] = pd.to_numeric(video_data12['Comments'])
#video_data12['CommentViewRatio'] = video_data12['Comments'] / video_data12['Views']

# For video_data13
video_data13['Published_date'] = pd.to_datetime(video_data13['Published_date']).dt.date
video_data13['Views'] = pd.to_numeric(video_data13['Views'])
video_data13['Likes'] = pd.to_numeric(video_data13['Likes'])
video_data13['Comments'] = pd.to_numeric(video_data13['Comments'])
video_data13['CommentViewRatio'] = video_data13['Comments'] / video_data13['Views']

# For video_data14
video_data14['Published_date'] = pd.to_datetime(video_data14['Published_date']).dt.date
video_data14['Views'] = pd.to_numeric(video_data14['Views'])
video_data14['Likes'] = pd.to_numeric(video_data14['Likes'])
video_data14['Comments'] = pd.to_numeric(video_data14['Comments'])
video_data14['CommentViewRatio'] = video_data14['Comments'] / video_data14['Views']

# For video_data15
video_data15['Published_date'] = pd.to_datetime(video_data15['Published_date']).dt.date
video_data15['Views'] = pd.to_numeric(video_data15['Views'])
video_data15['Likes'] = pd.to_numeric(video_data15['Likes'])
video_data15['Comments'] = pd.to_numeric(video_data15['Comments'])
video_data15['CommentViewRatio'] = video_data15['Comments'] / video_data15['Views']

# Ensure the necessary operations are applied uniformly across all DataFrames.



video_data
# Out:
#                                                  Title Published_date  Views  \
# 0                                            Session 4     2023-10-18     85
# 1                                            Session 3     2023-10-18     83
# 2                                            Session 2     2023-10-18     76
# 3                                            Session 1     2023-10-18    290
# 4                                         24 July 2023     2023-07-24     65
# ..                                                 ...            ...    ...
# 390                     MIT Graduate School Experience     2019-03-06    174
# 391              Entrepreneurship - The Journey Within     2019-01-23    308
# 392                            MS In USA (Electronics)     2018-10-28    736
# 393        How to get into Top US Colleges for MS - CS     2018-10-22    267
# 394  STTP on ROSMD-2020 Day 1: First Talk (Shri. H ...     2020-10-22     16
#
#      Likes  Comments  CommentViewRatio
# ...

# %%
from googleapiclient.discovery import build
import isodate

# Set up the API key and API service name
api_key = "AIzaSyDQLPUNa97noGvgDkH9u00kUc7HM2P_mWA"  # Replace with your own API key
youtube = build('youtube', 'v3', developerKey=api_key)

def get_video_durations(video_ids):
    durations = []
    for video_id in video_ids:
        request = youtube.videos().list(
            part="contentDetails",
            id=video_id
        )
        response = request.execute()
        duration = response['items'][0]['contentDetails']['duration']
        parsed_duration = isodate.parse_duration(duration)
        durations.append(parsed_duration.total_seconds())
    return durations

#print("Durations of the videos are:")
#for i, duration in enumerate(durations):
  #  print({duration})

# %%
durations = get_video_durations(video_ids)
video_data['durations'] = durations


durations1 = get_video_durations(video_ids1)
video_data1['durations'] = durations1

# Repeat the above for video_data2 to video_data15
durations2 = get_video_durations(video_ids2)
video_data2['durations'] = durations2

durations3 = get_video_durations(video_ids3)
video_data3['durations'] = durations3

durations4 = get_video_durations(video_ids4)
video_data4['durations'] = durations4

durations5 = get_video_durations(video_ids5)
video_data5['durations'] = durations5

durations6 = get_video_durations(video_ids6)
video_data6['durations'] = durations6

durations7 = get_video_durations(video_ids7)
video_data7['durations'] = durations7

durations8 = get_video_durations(video_ids8)
video_data8['durations'] = durations8

durations9 = get_video_durations(video_ids9)
video_data9['durations'] = durations9

durations10 = get_video_durations(video_ids10)
video_data10['durations'] = durations10

durations11 = get_video_durations(video_ids11)
video_data11['durations'] = durations11

#durations12 = get_video_durations(video_ids12)
#video_data12['durations'] = durations12

durations13 = get_video_durations(video_ids13)
video_data13['durations'] = durations13

durations14 = get_video_durations(video_ids14)
video_data14['durations'] = durations14

durations15 = get_video_durations(video_ids15)
video_data15['durations'] = durations15

# %%
top10_videos = video_data.sort_values(by='Views',ascending=False)
top10_videos
# Out:
#                                                  Title Published_date  Views  \
# 322    IIITDM KANCHEEPURAM | Flash Mob 2018 | ZHILAT |     2018-10-24  25426
# 350             10th Convocation - IIITDM Kancheepuram     2022-09-10  17978
# 323  IIITDM Kancheepuram | Freshie 2018 - 'Zhilat' ...     2018-10-11  17760
# 366                8th CONVOCATION IIITDM KANCHEEPURAM     2020-10-31   8735
# 346  Welcome to IIITDM Kancheepuram: Campus Tour an...     2023-04-13   8361
# ..                                                 ...            ...    ...
# 220  Optics - Part 2 | Science | NTSE NMMS | Vidhai...     2022-02-25      1
# 229  Plant Anatomy and Plant Physiology - Part 2 | ...     2022-01-14      1
# 349    IIITDM Kancheepuram First Year Orientation 2022     2022-11-08      0
# 369          8th Convocation 2020, IIITDM Kancheepuram     2020-10-16      0
# 370    IIITDM Kancheepuram First Year Orientation 2022     2020-10-16      0
#
# ...

# %%
ax1 = sns.barplot(x='Views', y = 'Title',data= top10_videos)
# Out:
# C:\Users\saraswati\anaconda3\Lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 2960 (\N{TAMIL LETTER AI}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\saraswati\anaconda3\Lib\site-packages\IPython\core\events.py:89: UserWarning: Matplotlib currently does not support Tamil natively.
#   func(*args, **kwargs)
# C:\Users\saraswati\anaconda3\Lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 2975 (\N{TAMIL LETTER TTA}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\saraswati\anaconda3\Lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 3007 (\N{TAMIL VOWEL SIGN I}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\saraswati\anaconda3\Lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 2991 (\N{TAMIL LETTER YA}) missing from current font.
#   func(*args, **kwargs)
# ...

# %%
video_data['Month'] = pd.to_datetime(video_data['Published_date']).dt.strftime('%b')
video_data
# Out:
#                                                  Title Published_date  Views  \
# 0                                            Session 4     2023-10-18     85
# 1                                            Session 3     2023-10-18     83
# 2                                            Session 2     2023-10-18     76
# 3                                            Session 1     2023-10-18    290
# 4                                         24 July 2023     2023-07-24     65
# ..                                                 ...            ...    ...
# 390                     MIT Graduate School Experience     2019-03-06    174
# 391              Entrepreneurship - The Journey Within     2019-01-23    308
# 392                            MS In USA (Electronics)     2018-10-28    736
# 393        How to get into Top US Colleges for MS - CS     2018-10-22    267
# 394  STTP on ROSMD-2020 Day 1: First Talk (Shri. H ...     2020-10-22     16
#
# ...

# %%
videos_per_month= video_data.groupby('Month',as_index=False).size()
videos_per_month
# Out:
#    Month  size
# 0    Apr    19
# 1    Aug    33
# 2    Dec    38
# 3    Feb    19
# 4    Jan    31
# 5    Jul    31
# 6    Jun    20
# 7    Mar    96
# 8    May    13
# 9    Nov    12
# 10   Oct    48
# 11   Sep    35

# %%
sortOrder = ['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec']

# %%
videos_per_month.index = pd.CategoricalIndex(videos_per_month['Month'],categories = sortOrder,ordered= True)

# %%
videos_per_month = videos_per_month.sort_index()

# %%
ax2 = sns.barplot(x='Month',y = 'size', data = videos_per_month)

# %%
ka = pd.DataFrame(channel_data.corr())
ka
# Out:
# C:\Users\saraswati\AppData\Local\Temp\ipykernel_19068\579418265.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   ka = pd.DataFrame(channel_data.corr())
#                       Subscribers     Views  Total_videos  \
# Subscribers              1.000000  0.948503      0.087004
# Views                    0.948503  1.000000      0.028528
# Total_videos             0.087004  0.028528      1.000000
# SubscriberViewsratio    -0.346125 -0.383378     -0.273434
# ViewsSubscriberratio     0.637462  0.797334      0.165642
#
#                       SubscriberViewsratio  ViewsSubscriberratio
# Subscribers                      -0.346125              0.637462
# Views                            -0.383378              0.797334
# Total_videos                     -0.273434              0.165642
# ...

# %% [markdown]
# #### video_data.to_csv("C:/Users/saraswati/Downloads/o1.csv")

# %%
ka = pd.DataFrame(channel_data.corr())

plt.imshow(ka)
# Out:
# C:\Users\saraswati\AppData\Local\Temp\ipykernel_19068\456209711.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   ka = pd.DataFrame(channel_data.corr())

# %%
ba = pd.DataFrame(video_data.corr())
ba
# Out:
# C:\Users\saraswati\AppData\Local\Temp\ipykernel_19068\2764507444.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   ba = pd.DataFrame(video_data.corr())
#                      Views     Likes  Comments  CommentViewRatio  durations
# Views             1.000000  0.849449  0.490488         -0.042304   0.206512
# Likes             0.849449  1.000000  0.700420         -0.008412   0.182760
# Comments          0.490488  0.700420  1.000000          0.159973   0.038281
# CommentViewRatio -0.042304 -0.008412  0.159973          1.000000  -0.014187
# durations         0.206512  0.182760  0.038281         -0.014187   1.000000

# %%
plt.imshow(ba)

# %%
from googleapiclient.discovery import build
import isodate

# Set up the API key and API service name
api_key = "AIzaSyDQLPUNa97noGvgDkH9u00kUc7HM2P_mWA"  # Replace with your own API key
youtube = build('youtube', 'v3', developerKey=api_key)

def get_video_durations(video_ids):
    durations = []
    for video_id in video_ids:
        request = youtube.videos().list(
            part="contentDetails",
            id=video_id
        )
        response = request.execute()
        duration = response['items'][0]['contentDetails']['duration']
        parsed_duration = isodate.parse_duration(duration)
        durations.append(parsed_duration.total_seconds())
    return durations

# Replace 'VIDEO_IDs' with the list of video IDs you want to check
#video_ids = ['McWwmSTF0LI', 'VIDEO_ID_2', 'VIDEO_ID_3']  # Add your video IDs here
durations = get_video_durations(video_ids)
print("Durations of the videos are:")
for i, duration in enumerate(durations):
    print(f"Video with ID {video_ids[i]} has a duration of {duration} seconds.")
# Out:
# Durations of the videos are:
# Video with ID 0lX_-yvAv10 has a duration of 1235.0 seconds.
# Video with ID vx4y9Cxb61s has a duration of 1195.0 seconds.
# Video with ID Tcx9tpaEvSU has a duration of 1270.0 seconds.
# Video with ID _G_uKq_Ts9c has a duration of 998.0 seconds.
# Video with ID O8Gyy1H9PQk has a duration of 16.0 seconds.
# Video with ID phk9VtWTWvE has a duration of 479.0 seconds.
# Video with ID G_ku9LMWl5k has a duration of 297.0 seconds.
# Video with ID McWwmSTF0LI has a duration of 391.0 seconds.
# Video with ID dtIuwhW1TRI has a duration of 652.0 seconds.
# Video with ID zBmKsKBJP7U has a duration of 534.0 seconds.
# Video with ID iyeXLCIDI0I has a duration of 528.0 seconds.
# Video with ID 8JfjupVkLlQ has a duration of 602.0 seconds.
# Video with ID m0xjAfdbnRc has a duration of 430.0 seconds.
# Video with ID KiwlbmGTOco has a duration of 310.0 seconds.
# Video with ID 2jtJAKeY2kc has a duration of 21.0 seconds.
# ...

# %%
plt.xticks(rotation=90)
ax2 = sns.barplot(x='Channel_name',y = 'Subscribers', data = channel_data)

# %%
df_subset = video_data.head(20)

# Plot the data from the subset
plt.plot(df_subset.index, df_subset['Views'], label='Views')
plt.plot(df_subset.index, df_subset['Title'], label='Title')
plt.plot(df_subset.index, df_subset['Likes'], label='Likes')



plt.xticks(rotation=90)


ax2 = sns.barplot(x='Title',y = 'Likes', data = video_data13)
